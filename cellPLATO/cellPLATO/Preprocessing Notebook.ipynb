# %% [markdown]
# # Preprocessing Notebook

# %% [markdown]
# Notebook to run through data processing steps using default settings, and save the resulting dataframes for use in the accompanying notebooks

# %%
import cellPLATO as cp

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

OVERWRITE_DATAFRAMES = True
# Out:
# Finished running cellPLATO initialization and loaded config.
# Initializing:  20x_100x_hightr
# Hypthesis testing using:  st.ttest_ind
# Plots will be exported to:  Z://Collaboration_data/Mace_Lab/my_generated/cellPLATO(dev)/20x_100x_hightr\2022-07-19_10-57-08-496096\plots/
# Using unique embedding per dataset shortname:  20x_100x_hightr
# Exporting static Superplots
# Exporting static Plots of Differences
# Exporting static Marginal scatterplots
# Exporting static Timeplots
# Exporting Bar plots
# Using corresponding CTL_SHORTLABEL:  WT_20x  for condition:  CAMWT_20x
# Dataset in current notebook:  20x_100x_hightr
# Finished initializing data_processing
# Finished intializing visualizations
# Finished initializing cellPLATO

# %%
# Get the experiment list from the experiments listed in the config 
exp_list = cp.populate_experiment_list()
display(exp_list)
# Out:
#       Condition                   Experiment                 Replicate_ID  \
# 0     CAMWT_20x  Condition_20x_ICAMWT_tracks  Condition_20x_ICAMWT_tracks
# 1     CAMKO_20x  Condition_20x_ICAMKO_tracks  Condition_20x_ICAMKO_tracks
# 2   NK92WT_100x              WT_100x_mScar_2              WT_100x_mScar_2
# 3   NK92WT_100x                     NK92WT_8                     NK92WT_8
# 4   NK92WT_100x                     NK92WT_5                     NK92WT_5
# 5   NK92WT_100x                     NK92WT_4                     NK92WT_4
# 6   NK92WT_100x                     NK92WT_3                     NK92WT_3
# 7   NK92WT_100x                     NK92WT_2                     NK92WT_2
# 8   NK92WT_100x                    NK92WT2_7                    NK92WT2_7
# 9   NK92WT_100x                    NK92WT2_6                    NK92WT2_6
# 10  NK92WT_100x                    NK92WT2_3                    NK92WT2_3
# 11  NK92WT_100x                       NK92WT                       NK92WT
# 12  NK92WT_100x              WT_100x_mScar_8              WT_100x_mScar_8
# 13  NK92WT_100x              WT_100x_mScar_9              WT_100x_mScar_9
# 14  NK92KO_100x                     NK92KO_x                     NK92KO_x
# 15  NK92KO_100x                     NK92KO_7                     NK92KO_7
# 16  NK92KO_100x                     NK92KO_5                     NK92KO_5
# 17  NK92KO_100x                     NK92KO_4                     NK92KO_4
# 18  NK92KO_100x                     NK92KO_3                     NK92KO_3
# 19  NK92KO_100x                     NK92KO_1                     NK92KO_1
# 20  NK92KO_100x                    NK92KO2_6                    NK92KO2_6
# 21  NK92KO_100x                    NK92KO2_4                    NK92KO2_4
# 22  NK92KO_100x                       NK92KO                       NK92KO
#
#    Condition_shortlabel Replicate_shortlabel
# 0                WT_20x             WT_20x_0
# 1                KO_20x             KO_20x_0
# 2               WT_100x            WT_100x_9
# 3               WT_100x            WT_100x_8
# 4               WT_100x            WT_100x_7
# 5               WT_100x            WT_100x_6
# 6               WT_100x            WT_100x_5
# 7               WT_100x            WT_100x_4
# 8               WT_100x            WT_100x_3
# 9               WT_100x            WT_100x_2
# 10              WT_100x            WT_100x_1
# 11              WT_100x            WT_100x_0
# 12              WT_100x           WT_100x_10
# 13              WT_100x           WT_100x_11
# 14              KO_100x            KO_100x_8
# 15              KO_100x            KO_100x_7
# 16              KO_100x            KO_100x_6
# 17              KO_100x            KO_100x_5
# 18              KO_100x            KO_100x_4
# 19              KO_100x            KO_100x_3
# 20              KO_100x            KO_100x_2
# 21              KO_100x            KO_100x_1
# 22              KO_100x            KO_100x_0

# %%
# Load, process and combine the dataframes (including segmentation and migration calculations)
comb_df = cp.combine_dataframes(exp_list)
# Out:
# ----
# ['CAMWT_20x', 'CAMKO_20x', 'NK92WT_100x', 'NK92KO_100x']
# ['WT_20x', 'KO_20x', 'WT_100x', 'KO_100x']
# [CAMWT_20x, CAMKO_20x, NK92WT_100x, NK92KO_100x]
# Categories (4, object): [CAMWT_20x, CAMKO_20x, NK92WT_100x, NK92KO_100x]
# ---
# 0    Condition_20x_ICAMWT_tracks
# Name: Experiment, dtype: object
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# h5 file contains dummies
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (437663, 11)
# coords:  (437663, 5)
# 0 CAMWT_20x 0.537
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\CAMWT_20x\Condition_20x_ICAMWT_tracks\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  CAMWT_20x
# Processing migration_calcs() for experiment:  Condition_20x_ICAMWT_tracks
# 100%|█████████████████████████████████████████████████████████████████████████████| 4989/4989 [01:54<00:00, 43.64it/s]
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\CAMWT_20x\Condition_20x_ICAMWT_tracks\seg_mig_calcs.csv
# 1    Condition_20x_ICAMKO_tracks
# Name: Experiment, dtype: object
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# h5 file contains dummies
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (761064, 11)
# coords:  (761064, 5)
# 1 CAMKO_20x 0.537
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\CAMKO_20x\Condition_20x_ICAMKO_tracks\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
#   0%|                                                                                       | 0/11167 [00:00<?, ?it/s]
# Processing migration_calcs() for condition:  CAMKO_20x
# Processing migration_calcs() for experiment:  Condition_20x_ICAMKO_tracks
# 100%|███████████████████████████████████████████████████████████████████████████| 11167/11167 [03:35<00:00, 51.72it/s]
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\CAMKO_20x\Condition_20x_ICAMKO_tracks\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 62.50it/s]
# 2     WT_100x_mScar_2
# 3            NK92WT_8
# 4            NK92WT_5
# 5            NK92WT_4
# 6            NK92WT_3
# 7            NK92WT_2
# 8           NK92WT2_7
# 9           NK92WT2_6
# 10          NK92WT2_3
# 11             NK92WT
# 12    WT_100x_mScar_8
# 13    WT_100x_mScar_9
# Name: Experiment, dtype: object
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (120, 11)
# coords:  (120, 5)
# 2 NK92WT_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\WT_100x_mScar_2\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92WT_100x
# Processing migration_calcs() for experiment:  WT_100x_mScar_2
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\WT_100x_mScar_2\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 63.06it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# h5 file contains dummies
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (389, 11)
# coords:  (389, 5)
# 2 NK92WT_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT_8\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92WT_100x
# Processing migration_calcs() for experiment:  NK92WT_8
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT_8\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 31.27it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (120, 11)
# coords:  (120, 5)
# 2 NK92WT_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT_5\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92WT_100x
# Processing migration_calcs() for experiment:  NK92WT_5
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT_5\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 31.19it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (120, 11)
# coords:  (120, 5)
# 2 NK92WT_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT_4\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92WT_100x
# Processing migration_calcs() for experiment:  NK92WT_4
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT_4\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 31.25it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (120, 11)
# coords:  (120, 5)
# 2 NK92WT_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT_3\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92WT_100x
# Processing migration_calcs() for experiment:  NK92WT_3
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT_3\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 76.93it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (49, 11)
# coords:  (49, 5)
# 2 NK92WT_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT_2\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92WT_100x
# Processing migration_calcs() for experiment:  NK92WT_2
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT_2\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 32.26it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (120, 11)
# coords:  (120, 5)
# 2 NK92WT_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT2_7\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92WT_100x
# Processing migration_calcs() for experiment:  NK92WT2_7
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT2_7\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 74.63it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (247, 11)
# coords:  (247, 5)
# 2 NK92WT_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT2_6\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92WT_100x
# Processing migration_calcs() for experiment:  NK92WT2_6
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT2_6\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 32.26it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (120, 11)
# coords:  (120, 5)
# 2 NK92WT_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT2_3\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92WT_100x
# Processing migration_calcs() for experiment:  NK92WT2_3
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT2_3\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 31.25it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (120, 11)
# coords:  (120, 5)
# 2 NK92WT_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92WT_100x
# Processing migration_calcs() for experiment:  NK92WT
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\NK92WT\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 60.61it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (124, 11)
# coords:  (124, 5)
# 2 NK92WT_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\WT_100x_mScar_8\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92WT_100x
# Processing migration_calcs() for experiment:  WT_100x_mScar_8
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\WT_100x_mScar_8\seg_mig_calcs.csv
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 116.28it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# h5 file contains dummies
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (153, 11)
# coords:  (153, 5)
# 2 NK92WT_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\WT_100x_mScar_9\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92WT_100x
# Processing migration_calcs() for experiment:  WT_100x_mScar_9
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92WT_100x\WT_100x_mScar_9\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 30.30it/s]
# 14     NK92KO_x
# 15     NK92KO_7
# 16     NK92KO_5
# 17     NK92KO_4
# 18     NK92KO_3
# 19     NK92KO_1
# 20    NK92KO2_6
# 21    NK92KO2_4
# 22       NK92KO
# Name: Experiment, dtype: object
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (120, 11)
# coords:  (120, 5)
# 3 NK92KO_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO_x\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92KO_100x
# Processing migration_calcs() for experiment:  NK92KO_x
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO_x\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 69.44it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# h5 file contains dummies
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (264, 11)
# coords:  (264, 5)
# 3 NK92KO_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO_7\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92KO_100x
# Processing migration_calcs() for experiment:  NK92KO_7
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO_7\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 29.41it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (120, 11)
# coords:  (120, 5)
# 3 NK92KO_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO_5\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92KO_100x
# Processing migration_calcs() for experiment:  NK92KO_5
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO_5\seg_mig_calcs.csv
# 100%|██████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 152.17it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# h5 file contains dummies
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (150, 11)
# coords:  (150, 5)
# 3 NK92KO_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO_4\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92KO_100x
# Processing migration_calcs() for experiment:  NK92KO_4
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO_4\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 31.25it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (240, 11)
# coords:  (240, 5)
# 3 NK92KO_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO_3\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92KO_100x
# Processing migration_calcs() for experiment:  NK92KO_3
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO_3\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 32.26it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (120, 11)
# coords:  (120, 5)
# 3 NK92KO_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO_1\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92KO_100x
# Processing migration_calcs() for experiment:  NK92KO_1
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO_1\seg_mig_calcs.csv
# 100%|████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 129.87it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# h5 file contains dummies
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (271, 11)
# coords:  (271, 5)
# 3 NK92KO_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO2_6\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92KO_100x
# Processing migration_calcs() for experiment:  NK92KO2_6
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO2_6\seg_mig_calcs.csv
# 100%|████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 131.30it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# h5 file contains dummies
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (360, 11)
# coords:  (360, 5)
# 3 NK92KO_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO2_4\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92KO_100x
# Processing migration_calcs() for experiment:  NK92KO2_4
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO2_4\seg_mig_calcs.csv
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 31.25it/s]
# h5 file contents:  <KeysViewHDF5 ['objects', 'segmentation', 'tracks']>
# 2D track with zero as z component. Forcing STC
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False
# h5_data passed t h5_to_df() contains regionprops, adding to df.
# Index(['area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity'],
#       dtype='object')
# props_arr:  (119, 11)
# coords:  (119, 5)
# 3 NK92KO_100x 0.107
# No column Replicate_ID, renaming Experiment column
# Overlap: []
# CALIBRATED_POS ==  False , Input positions in pixels.
# Index(['frame', 'x', 'y', 'z', '_', 'particle', 'area', 'bbox_area',
#        'eccentricity', 'equivalent_diameter', 'extent', 'filled_area',
#        'major_axis_length', 'minor_axis_length', 'orientation', 'perimeter',
#        'solidity', 'Condition', 'Replicate_ID', 'Cond_label', 'Rep_label',
#        'x_um', 'y_um', 'x_pix', 'y_pix'],
#       dtype='object')
# Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO\seg_mig_calcs.csv doesnt already exist, processing input data:
# Processing migration calculations of pooled data
# Processing migration_calcs() for condition:  NK92KO_100x
# Processing migration_calcs() for experiment:  NK92KO
# Saving file: Z://Collaboration_data/Mace_Lab/20x_100x/20x_100x_high_temp_res\NK92KO_100x\NK92KO\seg_mig_calcs.csv
# max x_pix:  1022.3125 , image width:  1024
# max y_pix:  1022.1304321289062 , image height:  1024
# max x_um:  548.9818125 , MICRONS_PER_PIXEL:  0.107
# max y_um:  548.8840420532227 , MICRONS_PER_PIXEL:  0.107

# %%
comb_df = cp.measurement_pipeline(comb_df)
# Out:
# Calculating ripleys p, K and L with radius:  25  (pixels)
# Calibrating with mixed_scaling =  True
# Using mixed_calibration.
# CAMWT_20x 0.537 0.016666666666666666
# CAMKO_20x 0.537 0.016666666666666666
# NK92WT_100x 0.107 0.016666666666666666
# NK92KO_100x 0.107 0.016666666666666666

# %%
# Process a time-averaged DataFrame
tavg_df = cp.time_average(comb_df)
display(tavg_df)
# Out:
#         Cond_label    Condition Condition_shortlabel       MSD  Rep_label  \
# 0        CAMWT_20x    CAMWT_20x               WT_20x  0.062310        0.0
# 1        CAMWT_20x    CAMWT_20x               WT_20x  0.066585        0.0
# 2        CAMWT_20x    CAMWT_20x               WT_20x  0.057600        0.0
# 3        CAMWT_20x    CAMWT_20x               WT_20x  0.113291        0.0
# 4        CAMWT_20x    CAMWT_20x               WT_20x  0.048824        0.0
# ...            ...          ...                  ...       ...        ...
# 15887  NK92KO_100x  NK92KO_100x              KO_100x  0.254249       21.0
# 15888  NK92KO_100x  NK92KO_100x              KO_100x  0.151851       21.0
# 15889  NK92KO_100x  NK92KO_100x              KO_100x  0.161359       21.0
# 15890  NK92KO_100x  NK92KO_100x              KO_100x  0.067173       21.0
# 15891  NK92KO_100x  NK92KO_100x              KO_100x  0.059227       22.0
#
#                       Replicate_ID Replicate_shortlabel        _        area  \
# 0      Condition_20x_ICAMWT_tracks             WT_20x_0  0.00000  248.843369
# 1      Condition_20x_ICAMWT_tracks             WT_20x_0  0.00000  175.874573
# 2      Condition_20x_ICAMWT_tracks             WT_20x_0  0.00000  181.448883
# 3      Condition_20x_ICAMWT_tracks             WT_20x_0  0.00000   70.133148
# 4      Condition_20x_ICAMWT_tracks             WT_20x_0  0.00000  168.854813
# ...                            ...                  ...      ...         ...
# 15887                    NK92KO2_4            KO_100x_7  0.00000  286.923401
# 15888                    NK92KO2_4            KO_100x_7  0.00000  290.741302
# 15889                    NK92KO2_4            KO_100x_7  0.03125  304.237122
# 15890                    NK92KO2_4            KO_100x_7  0.00000  180.138565
# 15891                       NK92KO            KO_100x_8  0.00000  397.953400
#
#        arrest_coefficient  ...  turn_angle        uniq_id  unique_id  \
# 0                0.997013  ...   -3.143857            inf        0.0
# 1                0.997199  ...   -2.787234            inf        1.0
# 2                0.997349  ...    1.411370            inf        2.0
# 3                0.993830  ...    1.300673            inf        3.0
# 4                0.999495  ...   -1.498908            inf        4.0
# ...                   ...  ...         ...            ...        ...
# 15887            1.000000  ...  -27.341115   1.096095e+05    15887.0
# 15888            1.000000  ...   -5.566527  6.206503e+133    15888.0
# 15889            1.000000  ...  -22.600198  6.597535e+125    15889.0
# 15890            1.000000  ...   -7.889581   2.112000e+03    15890.0
# 15891            1.000000  ...    2.313164            inf    15891.0
#
#                 x       x_pix        x_um           y       y_pix       y_um  \
# 0      480.314640  480.314640  257.928962   20.107899   20.107899  10.797942
# 1      997.558980  997.558980  535.689172   20.735702   20.735702  11.135072
# 2      633.371408  633.371408  340.120446   19.053602   19.053602  10.231784
# 3      522.862362  522.862362  280.777089   25.941807   25.941807  13.930750
# 4       10.658516   10.658516    5.723623   25.649865   25.649865  13.773978
# ...           ...         ...         ...         ...         ...        ...
# 15887  415.961380  415.961380   44.507868  497.854019  497.854019  53.270380
# 15888  428.255510  428.255510   45.823340  640.980072  640.980072  68.584868
# 15889  381.270966  381.270966   40.795993  486.813790  486.813790  52.089076
# 15890  412.935425  412.935425   44.184090  430.355225  430.355225  46.048009
# 15891  514.238517  514.238517   55.023521  390.748847  390.748847  41.810127
#
#               z
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
# ...         ...
# 15887  0.000000
# 15888  0.000000
# 15889  0.024624
# 15890  0.000000
# 15891  0.000000
#
# [15892 rows x 48 columns]

# %%
# Make summary calculations from time-averaged dataframe
#Per condition:
avg_df = cp.average_per_condition(tavg_df)

# Per replicate
repavg_df = cp.average_per_condition(tavg_df, avg_per_rep=True)

# %%
# Dimension reduction pipeline
dr_df = cp.dr_pipeline(comb_df, dr_factors=cp.DR_FACTORS)
# Out:
# Running dr_pipeline...
# tSNE perplexity =  185
# UMAP nearest neighbors =  10  min distance =  0.5
# Using standardized factors for dimensionality reduction, matrix shape:  (1117936, 28)
# Using openTSNE with perplexity =  185
# Using openTSNE to calculate new embedding for input data.

# %%
# Clustering cell behavior
lab_dr_df = cp.hdbscan_clustering(dr_df, cluster_by=cp.CLUSTER_BY, plot=False)

# %%
# Run the trajectory clustering pipeline
lab_dr_df, traj_list, cluster_lst = cp.trajectory_clustering_pipeline(lab_dr_df, traj_factor='umap', dist_metric='hausdorff', filename_out='std_dr_df_traj')

# %%
cp.cluster_switching_pipeline(lab_dr_df)

# %%
if OVERWRITE_DATAFRAMES:
    # Save dataframes to shared data folder
    tavg_df.to_csv(cp.SAVED_DATA_PATH + 'tavg_df.csv')
    comb_df.to_csv(cp.SAVED_DATA_PATH + 'comb_df.csv')
    dr_df.to_csv(cp.SAVED_DATA_PATH + 'dr_df.csv')
    lab_dr_df.to_csv(cp.SAVED_DATA_PATH + 'lab_dr_df.csv')

# %% [markdown]
# ### Alternatively, run all the pipelines in a single cell, generate and save all outputs

# %%
#Minimal pipelines:
comb_df = cp.combine_dataframes(cp.populate_experiment_list())
comb_df = cp.measurement_pipeline(comb_df)
dr_df = cp.dr_pipeline(comb_df, dr_factors=cp.DR_FACTORS) 
cp.comparative_visualization_pipeline(dr_df)
lab_dr_df = cp.cluster_analysis_pipeline(dr_df,cp.CLUSTER_BY)
lab_dr_df, traj_list, cluster_lst = cp.trajectory_clustering_pipeline(lab_dr_df, traj_factor=CLUSTER_BY, dist_metric='hausdorff', filename_out='std_dr_df_traj')
cp.cluster_switching_pipeline(lab_dr_df)

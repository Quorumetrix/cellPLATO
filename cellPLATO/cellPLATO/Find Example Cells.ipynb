# %% [markdown]
# # Find Example Cells

# %%
import cellPLATO as cp

import numpy as np
import pandas as pd
# Out:
# Finished running cellPLATO initialization and loaded config.
# Initializing:  consistency_test_btrack_v2
# Hypthesis testing using:  st.ttest_ind
# Plots will be exported to:  Z://Collaboration_data/Mace_Lab/my_generated/cellPLATO(dev)/consistency_test_btrack_v2\2022-07-19_11-15-17-431379\plots/
# Using unique embedding per dataset shortname:  consistency_test_btrack_v2
# Exporting static Superplots
# Exporting static Plots of Differences
# Exporting static Marginal scatterplots
# Exporting static Timeplots
# Exporting Bar plots
# Using corresponding CTL_SHORTLABEL:  WT Day 0  for condition:  Condition_Day0_Stablized WTEL08_B5
# Dataset in current notebook:  consistency_test_btrack_v2
# Finished initializing data_processing
# Finished intializing visualizations
# Finished initializing cellPLATO

# %%
lab_dr_df = pd.read_csv(cp.SAVED_DATA_PATH + 'lab_dr_df.csv')
lab_dr_df
# Out:
#       Unnamed: 0  rep_row_ind  frame           x           y    z    _  \
# 0              0            0    4.0  112.414635   18.713415  0.0  0.0
# 1              1            1    5.0  110.486336   19.491804  0.0  0.0
# 2              2            2    6.0  110.511963   18.669857  0.0  0.0
# 3              3            3    7.0  110.015305   17.836735  0.0  0.0
# 4              4            4    8.0  108.599998   19.254999  0.0  0.0
# ...          ...          ...    ...         ...         ...  ...  ...
# 9329        9329         2958   56.0  183.507462  259.044769  0.0  0.0
# 9330        9330         2959   56.0  285.191162  305.066162  0.0  0.0
# 9331        9331         2960   56.0  181.603958   24.831684  0.0  0.0
# 9332        9332         2961   56.0   81.025002  183.725006  0.0  0.0
# 9333        9333         2962   56.0  331.130829   25.093458  0.0  0.0
#
#       particle       area  bbox_area  ...       PC7       PC8       PC9  \
# ...

# %% [markdown]
# ### Examine random cells

# %%
rand_cell_df = cp.get_random_cell(lab_dr_df)
cp.plot_cell_trajectories(rand_cell_df, lab_dr_df, dr_method='umap',contour_scale=1/5)   # Recall contour_scale doing nothing
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 21.05it/s]
# loading:  Z://Collaboration_data/Mace_Lab/h5/20211019T170641Z\Condition_Day7_Stablized WTEL08_B5\Day7_Stablized WTEL08_B5_3_mask_avg_tracks
# 2D track with zero as z component. Forcing STC
# h5 file contains dummies
# btrack_unpack() found h5 file containing regionprops:
# <HDF5 group "/objects/obj_type_1/properties" (12 members)>
# False

# %%
f=cp.plot_cell_metrics(rand_cell_df, 10)

# %%
# if(ANIMATE_TRAJECTORIES):
this_cell_id = cp.get_cell_id(rand_cell_df)
# Animate this cells trajectory.
cp.animate_t_window(rand_cell_df, lab_dr_df, dr_method='tSNE', cid='rand_'+this_cell_id)
cp.animate_t_window(rand_cell_df, lab_dr_df, dr_method='umap', cid='rand_'+this_cell_id)


'''
Issue with the t_window??
'''

# %% [markdown]
# ### Find cells with defined characteristics

# %%
# Get cells that reflect specific changes of interest. 
factor = 'aspect'
mean_std_df = get_cell_mean_variance(lab_dr_df, factor, sortby='std')

# factor = 'area'
# mean_std_df = get_cell_mean_variance(dr_df, factor, sortby='std')

n_samples = 5
tpt_cutoff = 20

for i in range(n_samples):

    this_cell_df = get_specific_cell(mean_std_df, lab_dr_df,i)
    
    # get this cells id
    this_cell_id = get_cell_id(this_cell_df)  
    
    plot_cell_trajectories(this_cell_df, lab_dr_df, dr_method='umap',contour_scale=1/5)   # Recall contour_scale doing nothing 
    
    
    if((len(this_cell_df) > tpt_cutoff) & ANIMATE_TRAJECTORIES):
        
        # Animate this cells trajectory.
        animate_t_window(this_cell_df, lab_dr_df, dr_method='umap', cid=factor+'_'+this_cell_id)

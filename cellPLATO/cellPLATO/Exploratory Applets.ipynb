# %% [markdown]
# # Exploratory Applets

# %%
from initialization.config import *
from visualization.panel_apps import *
# Out:
# Dataset in current notebook:  consistency_test_btrack_v2
# Initializing:  consistency_test_btrack_v2
# Hypthesis testing using:  st.ttest_ind
# Plots will be exported to:  Z://Collaboration_data/Mace_Lab/my_generated/cellPLATO(dev)/consistency_test_btrack_v2\2022-07-13_14-44-27-689308\plots/
# Using unique embedding per dataset shortname:  consistency_test_btrack_v2
# Exporting static Superplots
# Exporting static Plots of Differences
# Exporting static Marginal scatterplots
# Exporting static Timeplots
# Exporting Bar plots
# Dataset in current notebook:  consistency_test_btrack_v2

# %%
from data_processing.cell_identifier import *
from data_processing.cleaning_formatting_filtering import *
from data_processing.clustering import *
from data_processing.data_io import *
from data_processing.data_wrangling import *
from data_processing.dimensionality_reduction import *
from data_processing.measurements import *
from data_processing.migration_calculations import *
from data_processing.pipelines import *
from data_processing.shape_calculations import *
from data_processing.statistics import *
from data_processing.time_calculations import *
from data_processing.trajectory_clustering import *

from visualization.comparative_visualization import *
from visualization.cluster_visualization import *
from visualization.filter_visualization import *
from visualization.low_dimension_visualization import *
from visualization.panel_apps import *
from visualization.plots_of_differences import *
from visualization.small_multiples import *
from visualization.superplots import *
from visualization.timecourse_visualization import *
from visualization.trajectory_visualization import *

# %%
lab_dr_df = pd.read_csv(SAVED_DATA_PATH + 'lab_dr_df.csv')
lab_dr_df
# Out:
#       Unnamed: 0  Unnamed: 0.1  rep_row_ind  frame           x           y  \
# 0              0             0            0    4.0  112.414635   18.713415
# 1              1             1            1    5.0  110.486336   19.491804
# 2              2             2            2    6.0  110.511963   18.669857
# 3              3             3            3    7.0  110.015305   17.836735
# 4              4             4            4    8.0  108.599998   19.254999
# ...          ...           ...          ...    ...         ...         ...
# 9329        9329          9329         2958   56.0  183.507462  259.044769
# 9330        9330          9330         2959   56.0  285.191162  305.066162
# 9331        9331          9331         2960   56.0  181.603958   24.831684
# 9332        9332          9332         2961   56.0   81.025002  183.725006
# 9333        9333          9333         2962   56.0  331.130829   25.093458
#
#         z    _  particle       area  ...       PC7       PC8       PC9  \
# 0     0.0  0.0       0.0  47.292516  ...  0.328013  0.374026  0.513829
# 1     0.0  0.0       0.0  52.771527  ... -0.611667  0.156344  0.293055
# 2     0.0  0.0       0.0  60.269121  ...  0.230450  0.867364  2.073431
# 3     0.0  0.0       0.0  56.520324  ...  0.327341  0.742256  0.112474
# 4     0.0  0.0       0.0  57.673800  ...  0.027861 -0.066942 -0.876941
# ...   ...  ...       ...        ...  ...       ...       ...       ...
# 9329  0.0  0.0    1418.0  19.320723  ...  0.939667  0.225070 -0.404616
# 9330  0.0  0.0    1424.0  39.218184  ... -0.019981  1.182796  0.000590
# 9331  0.0  0.0    1425.0  29.125269  ...  1.187111 -0.999715  1.226251
# 9332  0.0  0.0    1434.0  23.069520  ...  0.700065 -0.882865 -1.578808
# 9333  0.0  0.0    1435.0  30.855483  ... -0.630263 -1.970884  0.529736
#
#           PC10      tSNE1      tSNE2      UMAP1     UMAP2  label  traj_id
# 0     0.291229  23.363518  10.478207  13.653425  4.081606      0     -1.0
# 1     1.336578  25.873318  13.136241  13.158578  5.438302      0     -1.0
# 2     0.164786  25.655955  14.504682  12.829719  5.906745      0     -1.0
# 3    -1.564421  28.053284  13.250576  13.515963  6.033869      0     -1.0
# 4    -1.055705  25.573479  13.698240  13.311677  5.464610      0     -1.0
# ...        ...        ...        ...        ...       ...    ...      ...
# 9329  1.277149  -3.253881 -11.517241  12.110229 -5.002064      0      NaN
# 9330 -0.160572  -5.518018   8.428832   9.495996  0.006860      0      NaN
# 9331 -1.125645   9.866251  -1.013107  14.315371 -1.307351      0      NaN
# 9332  0.242197 -24.168737 -11.204189   0.567138  3.944263      1      NaN
# 9333 -2.937976   3.319166  -1.084406  11.401782 -0.816705      0      NaN
#
# [9334 rows x 67 columns]

# %%
# Panel app to interactively explore the effect of filtering
explorer = ScatterExplorer(lab_dr_df)
explorer.panel().servable()
# Out:
# Row
#     [0] Column(margin=5, name='ScatterExplorer', width=300)
#         [0] StaticText(value='<b>ScatterExplorer</b>')
#         [1] Select(name='X variable', options=OrderedDict([('area', ...]), value='area')
#         [2] Select(name='Y variable', options=OrderedDict([('area', ...]), value='speed')
#         [3] IntSlider(end=50, name='Frame', start=1, value=50, value_throttled=50)
#         [4] Select(name='Filt1', options=OrderedDict([('area', ...]), value='speed')
#         [5] FloatSlider(end=200.0, name='Filt1 thresh', start=-100.0, value_throttled=0.0)
#         [6] Select(name='Filt2', options=OrderedDict([('area', ...]), value='area')
#         [7] RangeSlider(end=400, name='Filt2 range', start=-100, value=(-100, 400.0), value_throttled=(-100, 400.0))
#         [8] Select(name='Filt3', options=OrderedDict([('area', ...]), value='area')
#         [9] RangeSlider(end=100.0, name='Filt3 range', start=-100.0, value=(-100.0, 100.0), value_throttled=(-100.0, 100.0))
#         [10] FloatSlider(name='Fraction to display', start=0.01, value=1.0, value_throttled=1.0)
#     [1] ParamMethod(method)

# %%
'''
KeyError: 'Condition'
'''

# Explore the dimensionaly-reduced data interactively with a jointplot.
exploratory_jointplot = JointExplorer(lab_dr_df)
exploratory_jointplot.panel().servable()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-927d86b779bd> in <module>
#       5 # Explore the dimensionaly-reduced data interactively with a jointplot.
#       6 exploratory_jointplot = JointExplorer(lab_dr_df)
# ----> 7 exploratory_jointplot.panel().servable()
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\new_module\visualization\panel_apps.py in panel(self)
#     269
#     270     def panel(self):
# --> 271         return pn.Row(self.param, self.plot)
#     272
#     273
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\layout\base.py in __init__(self, *objects, **params)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\layout\base.py in <listcomp>(.0)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\pane\base.py in panel(obj, **kwargs)
#      49     if kwargs.get('name', False) is None:
#      50         kwargs.pop('name')
# ---> 51     pane = PaneBase.get_pane_type(obj, **kwargs)(obj, **kwargs)
#      52     if len(pane.layout) == 1 and pane._unpack:
#      53         return pane.layout[0]
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\param.py in __init__(self, object, **params)
#     686         if object is not None:
#     687             self._validate_object()
# --> 688             self._replace_pane(not self.lazy)
#     689
#     690     @param.depends('object', watch=True)
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\param.py in _replace_pane(self, force, *args)
#     729                     new_object = Spacer()
#     730                 else:
# --> 731                     new_object = self.eval(self.object)
#     732                 self._update_inner(new_object)
#     733             finally:
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\param.py in eval(self, function)
#     719                 args = (getattr(dep.owner, dep.name) for dep in arg_deps)
#     720                 kwargs = {n: getattr(dep.owner, dep.name) for n, dep in kw_deps.items()}
# --> 721         return function(*args, **kwargs)
#     722
#     723     def _replace_pane(self, *args, force=False):
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\param\parameterized.py in _depends(*args, **kw)
#     349     @wraps(func)
#     350     def _depends(*args,**kw):
# --> 351         return func(*args,**kw)
#     352
#     353     deps = list(dependencies)+list(kw.values())
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\new_module\visualization\panel_apps.py in plot(self)
#     266     @param.depends('X_variable', 'Y_variable', 'frame', 'marginals', 'cond', 'rep') # , 'rep_i'
#     267     def plot(self):
# --> 268         return get_jointplot(self.df_in, self.X_variable, self.Y_variable, self.marginals, self.frame, self.cond, self.rep) # , self.rep_i)#
#     269
#     270     def panel(self):
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\new_module\visualization\panel_apps.py in get_jointplot(df_in, X_variable, Y_variable, marginals, frame, cond, rep)
#     247                             title="Exploratory jointplot: " + rep, trendline="ols",
#     248                             range_x = [bounds[0], bounds[1]],
# --> 249                             range_y = [bounds[2], bounds[3]])
#     250
#     251     return fig
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\plotly\express\_chart_types.py in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_color_override, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      62     mark in 2D space.
#      63     """
# ---> 64     return make_figure(args=locals(), constructor=go.Scatter)
#      65
#      66
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\plotly\express\_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1859                 prefix = get_label(args, args["facet_row"]) + "="
#    1860                 row_labels = [prefix + str(s) for s in sorted_group_values[m.grouper]]
# -> 1861             for val in sorted_group_values[m.grouper]:
#    1862                 if val not in m.val_map:
#    1863                     m.val_map[val] = m.sequence[len(m.val_map) % len(m.sequence)]
#
# KeyError: 'Condition'

# %%
'''
Make one of these explorers for umap too.
'''

# Interactive panel app to tweak DBScan paramters
tsne_db = TsneDbscanExplorer(lab_dr_df)
tsne_db.panel().servable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-90cee29a333a> in <module>
#       5 # Interactive panel app to tweak DBScan paramters
#       6 tsne_db = TsneDbscanExplorer(lab_dr_df)
# ----> 7 tsne_db.panel().servable()
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\new_module\visualization\panel_apps.py in panel(self)
#     441
#     442     def panel(self):
# --> 443         return pn.Row(self.param, self.plot)
#     444
#     445     def do_tsne(self, df):#x):
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\layout\base.py in __init__(self, *objects, **params)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\layout\base.py in <listcomp>(.0)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\pane\base.py in panel(obj, **kwargs)
#      49     if kwargs.get('name', False) is None:
#      50         kwargs.pop('name')
# ---> 51     pane = PaneBase.get_pane_type(obj, **kwargs)(obj, **kwargs)
#      52     if len(pane.layout) == 1 and pane._unpack:
#      53         return pane.layout[0]
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\param.py in __init__(self, object, **params)
#     686         if object is not None:
#     687             self._validate_object()
# --> 688             self._replace_pane(not self.lazy)
#     689
#     690     @param.depends('object', watch=True)
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\param.py in _replace_pane(self, force, *args)
#     729                     new_object = Spacer()
#     730                 else:
# --> 731                     new_object = self.eval(self.object)
#     732                 self._update_inner(new_object)
#     733             finally:
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\param.py in eval(self, function)
#     719                 args = (getattr(dep.owner, dep.name) for dep in arg_deps)
#     720                 kwargs = {n: getattr(dep.owner, dep.name) for n, dep in kw_deps.items()}
# --> 721         return function(*args, **kwargs)
#     722
#     723     def _replace_pane(self, *args, force=False):
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\param\parameterized.py in _depends(*args, **kw)
#     349     @wraps(func)
#     350     def _depends(*args,**kw):
# --> 351         return func(*args,**kw)
#     352
#     353     deps = list(dependencies)+list(kw.values())
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\new_module\visualization\panel_apps.py in plot(self)
#     438
#     439     def plot(self):
# --> 440         return self.get_plot()
#     441
#     442     def panel(self):
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\new_module\visualization\panel_apps.py in get_plot(self)
#     498
#     499         palette = PALETTE#'tab10'
# --> 500         sns.scatterplot(ax=axes[0], data=dr_df, x='tSNE1', y='tSNE2', palette=palette, hue='label', legend=False)
#     501
#     502         # Get a colormap the length of the list of labels
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     796         x_bins=x_bins, y_bins=y_bins,
#     797         estimator=estimator, ci=ci, n_boot=n_boot,
# --> 798         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#     799     )
#     800
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     578         )
#     579
# --> 580         super().__init__(data=data, variables=variables)
#     581
#     582         self.alpha = alpha
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     666             self.input_format = "long"
#     667             plot_data, variables = self._assign_variables_longform(
# --> 668                 data, **variables,
#     669             )
#     670
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     909         # Construct a tidy plot DataFrame. This will convert a number of
#     910         # types automatically, aligning on index in case of pandas objects
# --> 911         plot_data = pd.DataFrame(plot_data)
#     912
#     913         # Reduce the variables dictionary to fields with valid data
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# --> 257     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     258
#     259
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      75     # figure out the index, if necessary
#      76     if index is None:
# ---> 77         index = extract_index(arrays)
#      78     else:
#      79         index = ensure_index(index)
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     356
#     357         if not indexes and not raw_lengths:
# --> 358             raise ValueError("If using all scalar values, you must pass an index")
#     359
#     360         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
# Explore re-embedding different replicates in the tsne embedding from a single replicate
# As a test for how reproducible/meaningful any clusters may be
embed = ReEmbeddingExplorer(lab_dr_df, perplexity=30)
embed.panel().servable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-6c26b9485e59> in <module>
#       2 # As a test for how reproducible/meaningful any clusters may be
#       3 embed = ReEmbeddingExplorer(lab_dr_df, perplexity=30)
# ----> 4 embed.panel().servable()
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\new_module\visualization\panel_apps.py in panel(self)
#     565
#     566     def panel(self):
# --> 567         return pn.Row(self.param, self.plot)
#     568
#     569     def do_tsne(self, df):#x):
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\layout\base.py in __init__(self, *objects, **params)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\layout\base.py in <listcomp>(.0)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\pane\base.py in panel(obj, **kwargs)
#      49     if kwargs.get('name', False) is None:
#      50         kwargs.pop('name')
# ---> 51     pane = PaneBase.get_pane_type(obj, **kwargs)(obj, **kwargs)
#      52     if len(pane.layout) == 1 and pane._unpack:
#      53         return pane.layout[0]
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\param.py in __init__(self, object, **params)
#     686         if object is not None:
#     687             self._validate_object()
# --> 688             self._replace_pane(not self.lazy)
#     689
#     690     @param.depends('object', watch=True)
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\param.py in _replace_pane(self, force, *args)
#     729                     new_object = Spacer()
#     730                 else:
# --> 731                     new_object = self.eval(self.object)
#     732                 self._update_inner(new_object)
#     733             finally:
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\param.py in eval(self, function)
#     719                 args = (getattr(dep.owner, dep.name) for dep in arg_deps)
#     720                 kwargs = {n: getattr(dep.owner, dep.name) for n, dep in kw_deps.items()}
# --> 721         return function(*args, **kwargs)
#     722
#     723     def _replace_pane(self, *args, force=False):
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\param\parameterized.py in _depends(*args, **kw)
#     349     @wraps(func)
#     350     def _depends(*args,**kw):
# --> 351         return func(*args,**kw)
#     352
#     353     deps = list(dependencies)+list(kw.values())
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\new_module\visualization\panel_apps.py in plot(self)
#     562
#     563     def plot(self):
# --> 564         return self.get_plot()
#     565
#     566     def panel(self):
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\new_module\visualization\panel_apps.py in get_plot(self)
#     648         # Subplots using seaborn
#     649         palette = PALETTE#'tab10'
# --> 650         sns.scatterplot(ax=axes[0], data=dr_df, x='tSNE1', y='tSNE2', palette=palette, hue='label', legend=False)
#     651
#     652         # Get a colormap the length of the list of labels
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     796         x_bins=x_bins, y_bins=y_bins,
#     797         estimator=estimator, ci=ci, n_boot=n_boot,
# --> 798         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#     799     )
#     800
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     578         )
#     579
# --> 580         super().__init__(data=data, variables=variables)
#     581
#     582         self.alpha = alpha
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     666             self.input_format = "long"
#     667             plot_data, variables = self._assign_variables_longform(
# --> 668                 data, **variables,
#     669             )
#     670
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     909         # Construct a tidy plot DataFrame. This will convert a number of
#     910         # types automatically, aligning on index in case of pandas objects
# --> 911         plot_data = pd.DataFrame(plot_data)
#     912
#     913         # Reduce the variables dictionary to fields with valid data
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# --> 257     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     258
#     259
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      75     # figure out the index, if necessary
#      76     if index is None:
# ---> 77         index = extract_index(arrays)
#      78     else:
#      79         index = ensure_index(index)
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     356
#     357         if not indexes and not raw_lengths:
# --> 358             raise ValueError("If using all scalar values, you must pass an index")
#     359
#     360         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
# Explore clustering by xy position, tSNE or PCA values
clust = ClusterExplorer(lab_dr_df)
clust.panel().servable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1694         blocks = form_blocks(arrays, names, axes)
# -> 1695         mgr = BlockManager(blocks, axes)
#    1696         mgr._consolidate_inplace()
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     142         if do_integrity_check:
# --> 143             self._verify_integrity()
#     144
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     344             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 345                 construction_error(tot_items, block.shape[1:], self.axes)
#     346         if len(self.items) != tot_items:
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\managers.py in construction_error(tot_items, block_shape, axes, e)
#    1718     raise ValueError(
# -> 1719         "Shape of passed values is {0}, indices imply {1}".format(passed, implied)
#    1720     )
#
# ValueError: Shape of passed values is (2, 3), indices imply (9334, 3)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-6a98ca1b2cc4> in <module>
#       1 # Explore clustering by xy position, tSNE or PCA values
#       2 clust = ClusterExplorer(lab_dr_df)
# ----> 3 clust.panel().servable()
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\new_module\visualization\panel_apps.py in panel(self)
#     722
#     723     def panel(self):
# --> 724         return pn.Row(self.param, self.plot)
#     725
#     726
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\layout\base.py in __init__(self, *objects, **params)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\layout\base.py in <listcomp>(.0)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\pane\base.py in panel(obj, **kwargs)
#      49     if kwargs.get('name', False) is None:
#      50         kwargs.pop('name')
# ---> 51     pane = PaneBase.get_pane_type(obj, **kwargs)(obj, **kwargs)
#      52     if len(pane.layout) == 1 and pane._unpack:
#      53         return pane.layout[0]
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\param.py in __init__(self, object, **params)
#     686         if object is not None:
#     687             self._validate_object()
# --> 688             self._replace_pane(not self.lazy)
#     689
#     690     @param.depends('object', watch=True)
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\param.py in _replace_pane(self, force, *args)
#     729                     new_object = Spacer()
#     730                 else:
# --> 731                     new_object = self.eval(self.object)
#     732                 self._update_inner(new_object)
#     733             finally:
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\panel\param.py in eval(self, function)
#     719                 args = (getattr(dep.owner, dep.name) for dep in arg_deps)
#     720                 kwargs = {n: getattr(dep.owner, dep.name) for n, dep in kw_deps.items()}
# --> 721         return function(*args, **kwargs)
#     722
#     723     def _replace_pane(self, *args, force=False):
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\param\parameterized.py in _depends(*args, **kw)
#     349     @wraps(func)
#     350     def _depends(*args,**kw):
# --> 351         return func(*args,**kw)
#     352
#     353     deps = list(dependencies)+list(kw.values())
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\new_module\visualization\panel_apps.py in plot(self)
#     719
#     720     def plot(self):
# --> 721         return self.get_plot()
#     722
#     723     def panel(self):
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\new_module\visualization\panel_apps.py in get_plot(self)
#     756         # Subplots using seaborn
#     757         palette = PALETTE#'tab10'
# --> 758         sns.scatterplot(ax=axes[0], data=dr_df, x=x_name, y=y_name, palette=palette, hue='label', legend=False)
#     759
#     760         # Get a colormap the length of the list of labels
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     796         x_bins=x_bins, y_bins=y_bins,
#     797         estimator=estimator, ci=ci, n_boot=n_boot,
# --> 798         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#     799     )
#     800
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     578         )
#     579
# --> 580         super().__init__(data=data, variables=variables)
#     581
#     582         self.alpha = alpha
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     666             self.input_format = "long"
#     667             plot_data, variables = self._assign_variables_longform(
# --> 668                 data, **variables,
#     669             )
#     670
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     909         # Construct a tidy plot DataFrame. This will convert a number of
#     910         # types automatically, aligning on index in case of pandas objects
# --> 911         plot_data = pd.DataFrame(plot_data)
#     912
#     913         # Reduce the variables dictionary to fields with valid data
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# --> 257     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     258
#     259
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      85     axes = [ensure_index(columns), index]
#      86
# ---> 87     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      88
#      89
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1697         return mgr
#    1698     except ValueError as e:
# -> 1699         construction_error(len(arrays), arrays[0].shape, axes, e)
#    1700
#    1701
#
# c:\users\tyler\anaconda3\envs\aquaeductum\lib\site-packages\pandas\core\internals\managers.py in construction_error(tot_items, block_shape, axes, e)
#    1717         raise ValueError("Empty data passed with indices specified.")
#    1718     raise ValueError(
# -> 1719         "Shape of passed values is {0}, indices imply {1}".format(passed, implied)
#    1720     )
#    1721
#
# ValueError: Shape of passed values is (2, 3), indices imply (9334, 3)

# %%
tsuperplot = SupertimePlotExplorer(lab_dr_df)
tsuperplot.panel().servable()
# Out:
# Row
#     [0] Column(margin=5, name='SupertimePlotExplorer', width=300)
#         [0] StaticText(value='<b>SupertimePlotExplorer<...)
#         [1] Select(name='Factor', options=OrderedDict([('area', ...]), value='area')
#         [2] IntSlider(end=50, name='T window', start=1, value=1, value_throttled=1)
#     [1] ParamMethod(method)

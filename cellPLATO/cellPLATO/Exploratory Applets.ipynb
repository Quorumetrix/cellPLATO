# %% [markdown]
# # Exploratory Applets

# %%
import cellPLATO as cp

import os
import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt
# import plotly.express as px
# Out:
# Finished running cellPLATO initialization and loaded config.
# Initializing:  consistency_test_btrack_v2
# Hypthesis testing using:  st.ttest_ind
# Plots will be exported to:  Z://Collaboration_data/Mace_Lab/my_generated/cellPLATO(dev)/consistency_test_btrack_v2\2022-07-22_09-08-59-717850\plots/
# Using unique embedding per dataset shortname:  consistency_test_btrack_v2
# Exporting static Superplots
# Exporting static Plots of Differences
# Exporting static Marginal scatterplots
# Exporting static Timeplots
# Exporting Bar plots
# Using corresponding CTL_SHORTLABEL:  WT Day 0  for condition:  Condition_Day0_Stablized WTEL08_B5
# Dataset in current notebook:  consistency_test_btrack_v2
# Finished initializing data_processing
# Finished intializing visualizations
# COND_LIST:  ['Condition_Day0_Stablized WTEL08_B5', 'Condition_Day7_Stablized WTEL08_B5', 'all']
# REP_LIST:  ['Day0_Stablized WTEL08_B5_1_mask_avg_tracks', 'Day0_Stablized WTEL08_B5_2_mask_avg_tracks', 'Day0_Stablized WTEL08_B5_3_mask_avg_tracks', 'Day7_Stablized WTEL08_B5_1_mask_avg_tracks', 'Day7_Stablized WTEL08_B5_2_mask_avg_tracks', 'Day7_Stablized WTEL08_B5_3_mask_avg_tracks', 'pooled']
# Finished initializing cellPLATO

# %%
if os.path.exists(cp.SAVED_DATA_PATH + 'dr_df.csv'):
    print(cp.SAVED_DATA_PATH + 'dr_df_.csv',' exists, loading dataframes...')
    
    # Load existing (preprocessed) data
    comb_df = pd.read_csv(cp.SAVED_DATA_PATH + 'comb_df.csv')
    dr_df = pd.read_csv(cp.SAVED_DATA_PATH + 'dr_df.csv')
    lab_dr_df = pd.read_csv(cp.SAVED_DATA_PATH + 'lab_dr_df.csv')
    tavg_df = pd.read_csv(cp.SAVED_DATA_PATH + 'tavg_df.csv')
else:
    
    print('File doesnt exist.')
# Out:
# Z://Collaboration_data/Mace_Lab/my_generated/cellPLATO(dev)/consistency_test_btrack_v2\saved_data/dr_df_.csv  exists, loading dataframes...

# %%
# Panel app to interactively explore the effect of filtering
explorer = cp.ScatterExplorer(lab_dr_df)
explorer.panel().servable()
# Out:
# Row
#     [0] Column(margin=5, name='ScatterExplorer', width=300)
#         [0] StaticText(value='<b>ScatterExplorer</b>')
#         [1] Select(name='X variable', options=OrderedDict([('area', ...]), value='area')
#         [2] Select(name='Y variable', options=OrderedDict([('area', ...]), value='speed')
#         [3] IntSlider(end=50, name='Frame', start=1, value=50, value_throttled=50)
#         [4] Select(name='Filt1', options=OrderedDict([('area', ...]), value='speed')
#         [5] FloatSlider(end=200.0, name='Filt1 thresh', start=-100.0, value_throttled=0.0)
#         [6] Select(name='Filt2', options=OrderedDict([('area', ...]), value='area')
#         [7] RangeSlider(end=400, name='Filt2 range', start=-100, value=(-100, 400.0), value_throttled=(-100, 400.0))
#         [8] Select(name='Filt3', options=OrderedDict([('area', ...]), value='area')
#         [9] RangeSlider(end=100.0, name='Filt3 range', start=-100.0, value=(-100.0, 100.0), value_throttled=(-100.0, 100.0))
#         [10] FloatSlider(name='Fraction to display', start=0.01, value=1.0, value_throttled=1.0)
#     [1] ParamMethod(method)

# %%
lab_dr_df.columns
# Out:
# Index(['Unnamed: 0', 'rep_row_ind', 'frame', 'x', 'y', 'z', '_', 'particle',
#        'area', 'bbox_area', 'eccentricity', 'equivalent_diameter', 'extent',
#        'filled_area', 'major_axis_length', 'minor_axis_length', 'orientation',
#        'perimeter', 'solidity', 'Condition', 'Replicate_ID', 'Cond_label',
#        'Rep_label', 'x_um', 'y_um', 'x_pix', 'y_pix', 'index',
#        'euclidean_dist', 'segment_length', 'cumulative_length', 'speed',
#        'orientedness', 'directedness', 'turn_angle', 'endpoint_dir_ratio',
#        'dir_autocorr', 'outreach_ratio', 'MSD', 'max_dist', 'glob_turn_deg',
#        'arrest_coefficient', 'Condition_shortlabel', 'Replicate_shortlabel',
#        'rip_p', 'rip_K', 'rip_L', 'aspect', 'uniq_id', 'ntpts', 'PC1', 'PC2',
#        'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', 'tSNE1',
#        'tSNE2', 'UMAP1', 'UMAP2', 'label', 'traj_id'],
#       dtype='object')

# %%
'''
KeyError: 'Condition'
'''

# Explore the dimensionaly-reduced data interactively with a jointplot.
exploratory_jointplot = cp.JointExplorer(comb_df)
exploratory_jointplot.panel().servable()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-c4f31545fa88> in <module>
#       5 # Explore the dimensionaly-reduced data interactively with a jointplot.
#       6 exploratory_jointplot = cp.JointExplorer(comb_df)
# ----> 7 exploratory_jointplot.panel().servable()
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\git_version\cellPLATO\cellPLATO\visualization\panel_apps.py in panel(self)
#     273
#     274     def panel(self):
# --> 275         return pn.Row(self.param, self.plot)
#     276
#     277
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\layout\base.py in __init__(self, *objects, **params)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\layout\base.py in <listcomp>(.0)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\pane\base.py in panel(obj, **kwargs)
#      49     if kwargs.get('name', False) is None:
#      50         kwargs.pop('name')
# ---> 51     pane = PaneBase.get_pane_type(obj, **kwargs)(obj, **kwargs)
#      52     if len(pane.layout) == 1 and pane._unpack:
#      53         return pane.layout[0]
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\param.py in __init__(self, object, **params)
#     686         if object is not None:
#     687             self._validate_object()
# --> 688             self._replace_pane(not self.lazy)
#     689
#     690     @param.depends('object', watch=True)
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\param.py in _replace_pane(self, force, *args)
#     729                     new_object = Spacer()
#     730                 else:
# --> 731                     new_object = self.eval(self.object)
#     732                 self._update_inner(new_object)
#     733             finally:
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\param.py in eval(self, function)
#     719                 args = (getattr(dep.owner, dep.name) for dep in arg_deps)
#     720                 kwargs = {n: getattr(dep.owner, dep.name) for n, dep in kw_deps.items()}
# --> 721         return function(*args, **kwargs)
#     722
#     723     def _replace_pane(self, *args, force=False):
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\param\parameterized.py in _depends(*args, **kw)
#     405         @wraps(func)
#     406         def _depends(*args, **kw):
# --> 407             return func(*args, **kw)
#     408
#     409     deps = list(dependencies)+list(kw.values())
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\git_version\cellPLATO\cellPLATO\visualization\panel_apps.py in plot(self)
#     270     @param.depends('X_variable', 'Y_variable', 'frame', 'marginals', 'cond', 'rep') # , 'rep_i'
#     271     def plot(self):
# --> 272         return get_jointplot(self.df_in, self.X_variable, self.Y_variable, self.marginals, self.frame, self.cond, self.rep) # , self.rep_i)#
#     273
#     274     def panel(self):
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\git_version\cellPLATO\cellPLATO\visualization\panel_apps.py in get_jointplot(df_in, X_variable, Y_variable, marginals, frame, cond, rep)
#     251                             title="Exploratory jointplot: " + rep, trendline="ols",
#     252                             range_x = [bounds[0], bounds[1]],
# --> 253                             range_y = [bounds[2], bounds[3]])
#     254
#     255     return fig
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\plotly\express\_chart_types.py in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_color_override, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      62     mark in 2D space.
#      63     """
# ---> 64     return make_figure(args=locals(), constructor=go.Scatter)
#      65
#      66
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\plotly\express\_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1859                 prefix = get_label(args, args["facet_row"]) + "="
#    1860                 row_labels = [prefix + str(s) for s in sorted_group_values[m.grouper]]
# -> 1861             for val in sorted_group_values[m.grouper]:
#    1862                 if val not in m.val_map:
#    1863                     m.val_map[val] = m.sequence[len(m.val_map) % len(m.sequence)]
#
# KeyError: 'Condition'

# %%
'''
Make one of these explorers for umap too.
'''

# Interactive panel app to tweak DBScan paramters
tsne_db = cp.TsneDbscanExplorer(lab_dr_df)
tsne_db.panel().servable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-b4a54ee2549e> in <module>
#       5 # Interactive panel app to tweak DBScan paramters
#       6 tsne_db = cp.TsneDbscanExplorer(lab_dr_df)
# ----> 7 tsne_db.panel().servable()
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\git_version\cellPLATO\cellPLATO\visualization\panel_apps.py in panel(self)
#     442
#     443     def panel(self):
# --> 444         return pn.Row(self.param, self.plot)
#     445
#     446     def do_tsne(self, df):#x):
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\layout\base.py in __init__(self, *objects, **params)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\layout\base.py in <listcomp>(.0)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\pane\base.py in panel(obj, **kwargs)
#      49     if kwargs.get('name', False) is None:
#      50         kwargs.pop('name')
# ---> 51     pane = PaneBase.get_pane_type(obj, **kwargs)(obj, **kwargs)
#      52     if len(pane.layout) == 1 and pane._unpack:
#      53         return pane.layout[0]
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\param.py in __init__(self, object, **params)
#     686         if object is not None:
#     687             self._validate_object()
# --> 688             self._replace_pane(not self.lazy)
#     689
#     690     @param.depends('object', watch=True)
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\param.py in _replace_pane(self, force, *args)
#     729                     new_object = Spacer()
#     730                 else:
# --> 731                     new_object = self.eval(self.object)
#     732                 self._update_inner(new_object)
#     733             finally:
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\param.py in eval(self, function)
#     719                 args = (getattr(dep.owner, dep.name) for dep in arg_deps)
#     720                 kwargs = {n: getattr(dep.owner, dep.name) for n, dep in kw_deps.items()}
# --> 721         return function(*args, **kwargs)
#     722
#     723     def _replace_pane(self, *args, force=False):
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\param\parameterized.py in _depends(*args, **kw)
#     405         @wraps(func)
#     406         def _depends(*args, **kw):
# --> 407             return func(*args, **kw)
#     408
#     409     deps = list(dependencies)+list(kw.values())
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\git_version\cellPLATO\cellPLATO\visualization\panel_apps.py in plot(self)
#     439
#     440     def plot(self):
# --> 441         return self.get_plot()
#     442
#     443     def panel(self):
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\git_version\cellPLATO\cellPLATO\visualization\panel_apps.py in get_plot(self)
#     499
#     500         palette = PALETTE#'tab10'
# --> 501         sns.scatterplot(ax=axes[0], data=dr_df, x='tSNE1', y='tSNE2', palette=palette, hue='label', legend=False)
#     502
#     503         # Get a colormap the length of the list of labels
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     796         x_bins=x_bins, y_bins=y_bins,
#     797         estimator=estimator, ci=ci, n_boot=n_boot,
# --> 798         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#     799     )
#     800
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     578         )
#     579
# --> 580         super().__init__(data=data, variables=variables)
#     581
#     582         self.alpha = alpha
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     666             self.input_format = "long"
#     667             plot_data, variables = self._assign_variables_longform(
# --> 668                 data, **variables,
#     669             )
#     670
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     909         # Construct a tidy plot DataFrame. This will convert a number of
#     910         # types automatically, aligning on index in case of pandas objects
# --> 911         plot_data = pd.DataFrame(plot_data)
#     912
#     913         # Reduce the variables dictionary to fields with valid data
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     389
#     390         if not indexes and not raw_lengths:
# --> 391             raise ValueError("If using all scalar values, you must pass an index")
#     392
#     393         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
# Explore re-embedding different replicates in the tsne embedding from a single replicate
# As a test for how reproducible/meaningful any clusters may be
embed = cp.ReEmbeddingExplorer(lab_dr_df, perplexity=30)
embed.panel().servable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-a436a4f1ca44> in <module>
#       2 # As a test for how reproducible/meaningful any clusters may be
#       3 embed = cp.ReEmbeddingExplorer(lab_dr_df, perplexity=30)
# ----> 4 embed.panel().servable()
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\git_version\cellPLATO\cellPLATO\visualization\panel_apps.py in panel(self)
#     566
#     567     def panel(self):
# --> 568         return pn.Row(self.param, self.plot)
#     569
#     570     def do_tsne(self, df):#x):
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\layout\base.py in __init__(self, *objects, **params)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\layout\base.py in <listcomp>(.0)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\pane\base.py in panel(obj, **kwargs)
#      49     if kwargs.get('name', False) is None:
#      50         kwargs.pop('name')
# ---> 51     pane = PaneBase.get_pane_type(obj, **kwargs)(obj, **kwargs)
#      52     if len(pane.layout) == 1 and pane._unpack:
#      53         return pane.layout[0]
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\param.py in __init__(self, object, **params)
#     686         if object is not None:
#     687             self._validate_object()
# --> 688             self._replace_pane(not self.lazy)
#     689
#     690     @param.depends('object', watch=True)
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\param.py in _replace_pane(self, force, *args)
#     729                     new_object = Spacer()
#     730                 else:
# --> 731                     new_object = self.eval(self.object)
#     732                 self._update_inner(new_object)
#     733             finally:
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\param.py in eval(self, function)
#     719                 args = (getattr(dep.owner, dep.name) for dep in arg_deps)
#     720                 kwargs = {n: getattr(dep.owner, dep.name) for n, dep in kw_deps.items()}
# --> 721         return function(*args, **kwargs)
#     722
#     723     def _replace_pane(self, *args, force=False):
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\param\parameterized.py in _depends(*args, **kw)
#     405         @wraps(func)
#     406         def _depends(*args, **kw):
# --> 407             return func(*args, **kw)
#     408
#     409     deps = list(dependencies)+list(kw.values())
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\git_version\cellPLATO\cellPLATO\visualization\panel_apps.py in plot(self)
#     563
#     564     def plot(self):
# --> 565         return self.get_plot()
#     566
#     567     def panel(self):
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\git_version\cellPLATO\cellPLATO\visualization\panel_apps.py in get_plot(self)
#     649         # Subplots using seaborn
#     650         palette = PALETTE#'tab10'
# --> 651         sns.scatterplot(ax=axes[0], data=dr_df, x='tSNE1', y='tSNE2', palette=palette, hue='label', legend=False)
#     652
#     653         # Get a colormap the length of the list of labels
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     796         x_bins=x_bins, y_bins=y_bins,
#     797         estimator=estimator, ci=ci, n_boot=n_boot,
# --> 798         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#     799     )
#     800
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     578         )
#     579
# --> 580         super().__init__(data=data, variables=variables)
#     581
#     582         self.alpha = alpha
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     666             self.input_format = "long"
#     667             plot_data, variables = self._assign_variables_longform(
# --> 668                 data, **variables,
#     669             )
#     670
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     909         # Construct a tidy plot DataFrame. This will convert a number of
#     910         # types automatically, aligning on index in case of pandas objects
# --> 911         plot_data = pd.DataFrame(plot_data)
#     912
#     913         # Reduce the variables dictionary to fields with valid data
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     389
#     390         if not indexes and not raw_lengths:
# --> 391             raise ValueError("If using all scalar values, you must pass an index")
#     392
#     393         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
# Explore clustering by xy position, tSNE or PCA values
clust = cp.ClusterExplorer(lab_dr_df)
clust.panel().servable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-be18c6468cc5> in <module>
#       1 # Explore clustering by xy position, tSNE or PCA values
#       2 clust = cp.ClusterExplorer(lab_dr_df)
# ----> 3 clust.panel().servable()
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\git_version\cellPLATO\cellPLATO\visualization\panel_apps.py in panel(self)
#     723
#     724     def panel(self):
# --> 725         return pn.Row(self.param, self.plot)
#     726
#     727
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\layout\base.py in __init__(self, *objects, **params)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\layout\base.py in <listcomp>(.0)
#     359                                  "as positional arguments or as a keyword, "
#     360                                  "not both." % type(self).__name__)
# --> 361             params['objects'] = [panel(pane) for pane in objects]
#     362         elif 'objects' in params:
#     363             params['objects'] = [panel(pane) for pane in params['objects']]
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\pane\base.py in panel(obj, **kwargs)
#      49     if kwargs.get('name', False) is None:
#      50         kwargs.pop('name')
# ---> 51     pane = PaneBase.get_pane_type(obj, **kwargs)(obj, **kwargs)
#      52     if len(pane.layout) == 1 and pane._unpack:
#      53         return pane.layout[0]
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\param.py in __init__(self, object, **params)
#     686         if object is not None:
#     687             self._validate_object()
# --> 688             self._replace_pane(not self.lazy)
#     689
#     690     @param.depends('object', watch=True)
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\param.py in _replace_pane(self, force, *args)
#     729                     new_object = Spacer()
#     730                 else:
# --> 731                     new_object = self.eval(self.object)
#     732                 self._update_inner(new_object)
#     733             finally:
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\panel\param.py in eval(self, function)
#     719                 args = (getattr(dep.owner, dep.name) for dep in arg_deps)
#     720                 kwargs = {n: getattr(dep.owner, dep.name) for n, dep in kw_deps.items()}
# --> 721         return function(*args, **kwargs)
#     722
#     723     def _replace_pane(self, *args, force=False):
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\param\parameterized.py in _depends(*args, **kw)
#     405         @wraps(func)
#     406         def _depends(*args, **kw):
# --> 407             return func(*args, **kw)
#     408
#     409     deps = list(dependencies)+list(kw.values())
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\git_version\cellPLATO\cellPLATO\visualization\panel_apps.py in plot(self)
#     720
#     721     def plot(self):
# --> 722         return self.get_plot()
#     723
#     724     def panel(self):
#
# E:\Documents\Professional\Jupyter notebooks\Git\cellPLATO\git_version\cellPLATO\cellPLATO\visualization\panel_apps.py in get_plot(self)
#     757         # Subplots using seaborn
#     758         palette = PALETTE#'tab10'
# --> 759         sns.scatterplot(ax=axes[0], data=dr_df, x=x_name, y=y_name, palette=palette, hue='label', legend=False)
#     760
#     761         # Get a colormap the length of the list of labels
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     796         x_bins=x_bins, y_bins=y_bins,
#     797         estimator=estimator, ci=ci, n_boot=n_boot,
# --> 798         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#     799     )
#     800
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     578         )
#     579
# --> 580         super().__init__(data=data, variables=variables)
#     581
#     582         self.alpha = alpha
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     666             self.input_format = "long"
#     667             plot_data, variables = self._assign_variables_longform(
# --> 668                 data, **variables,
#     669             )
#     670
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     909         # Construct a tidy plot DataFrame. This will convert a number of
#     910         # types automatically, aligning on index in case of pandas objects
# --> 911         plot_data = pd.DataFrame(plot_data)
#     912
#     913         # Reduce the variables dictionary to fields with valid data
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      93     axes = [columns, index]
#      94
# ---> 95     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      96
#      97
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1704         return mgr
#    1705     except ValueError as e:
# -> 1706         raise construction_error(len(arrays), arrays[0].shape, axes, e)
#    1707
#    1708
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1700     try:
#    1701         blocks = _form_blocks(arrays, names, axes)
# -> 1702         mgr = BlockManager(blocks, axes)
#    1703         mgr._consolidate_inplace()
#    1704         return mgr
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     141
#     142         if do_integrity_check:
# --> 143             self._verify_integrity()
#     144
#     145         # Populate known_consolidate, blknos, and blklocs lazily
#
# c:\users\tyler\anaconda3\envs\cellplato_testjuly22\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     321         for block in self.blocks:
#     322             if block.shape[1:] != mgr_shape[1:]:
# --> 323                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     324         if len(self.items) != tot_items:
#     325             raise AssertionError(
#
# ValueError: Shape of passed values is (2, 3), indices imply (9334, 3)

# %%
tsuperplot = cp.SupertimePlotExplorer(lab_dr_df)
tsuperplot.panel().servable()
# Out:
# Row
#     [0] Column(margin=5, name='SupertimePlotExplorer', width=300)
#         [0] StaticText(value='<b>SupertimePlotExplorer<...)
#         [1] Select(name='Factor', options=OrderedDict([('area', ...]), value='area')
#         [2] IntSlider(end=50, name='T window', start=1, value=1, value_throttled=1)
#     [1] ParamMethod(method)
